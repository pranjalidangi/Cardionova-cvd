# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("✅ Cardionova ML Environment READY!")
print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print("Setup COMPLETE - You're ready for ML!")
# Out:
# ✅ Cardionova ML Environment READY!
# Pandas: 2.3.3
# NumPy: 2.2.6
# Setup COMPLETE - You're ready for ML!
